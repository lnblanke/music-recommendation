# %%
import pandas as pd
recset = pd.read_csv("data/recom_songs.csv")
recset["track_genre"].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
#        'new-age', 'opera', 'pagode', 'party', 'piano', 'pop-film', 'pop',
#        'power-pop', 'progressive-house', 'psych-rock', 'punk-rock',
#        'punk', 'r-n-b', 'reggae', 'reggaeton', 'rock-n-roll', 'rock',
#        'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
#        'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
#        'soul', 'spanish', 'study', 'swedish', 'synth-pop', 'tango',
#        'techno', 'trance', 'trip-hop', 'turkish', 'world-music'],
#       dtype=object)

# %%
recset = recset.drop(recset.columns[0], axis = 1).drop_duplicates()
recset
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music
#
# [113550 rows x 20 columns]

# %%
genre_dict = {0: 'blues',
 1: 'classical',
 2: 'country',
 3: 'disco',
 4: 'hip-hop',
 5: 'jazz',
 6: 'metal',
 7: 'pop',
 8: 'reggae',
 9: 'rock'}

# %%
# recommendation based on user's upload
import torch
import torch.nn as nn
import numpy as np
from sklearn.preprocessing import StandardScaler
from joblib import load

# input parameter "uplaod" is the path of csv file created by function ProcessUploadMusic
def upload_recommend(upload):
    model = nn.Sequential(
        nn.Dropout(0.2),
        nn.Linear(57, 512),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(256, 128),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(64, 32),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(32, 10),
    )
    
    model.load_state_dict(torch.load("weights"))
    model.eval()
    df = pd.read_csv(upload).tail(1)
    df = df.drop(df.columns[[0,1,-1]], axis = 1)
    scaler = load(open("scaler.pkl", "rb"))
    df = scaler.transform(df)
    tensor_data = torch.tensor(df, dtype=torch.float32)
    with torch.no_grad():
        y_pred = model(tensor_data)
    ind = int(torch.argmax(y_pred, -1))
    recommend = recset[recset["track_genre"] == genre_dict[ind]].sample(n = 10)
    return recommend[['artists', 'album_name', 'track_name', 'track_genre']]

# %%
#test upload_recommend
upload_recommend("data/test/test.csv")
# Out:
# d:\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
#                            artists                             album_name  \
# 19137             Bailey Zimmerman  Oklahoma Smokeshow - Breakout Country
# 19928                     Upchurch                              River Rat
# 19908                   Luke Bryan                         Crash My Party
# 19015         Florida Georgia Line                      Sad Country Songs
# 19790  BEIST;Stjørna Heimbrentslag                       Kongen av campen
# 19000     Dan + Shay;Justin Bieber      10,000 Hours (with Justin Bieber)
# 19779                 Tyler Braden                     Country Road Songs
# 19249    Willie Nelson;Norah Jones                      Desayuno en calma
# 19405               Brett Eldredge                   Hideaway - New Boots
# 19811              Little Big Town                            Pain Killer
#
#                               track_name track_genre
# 19137                       Fall in Love     country
# 19928                               Busy     country
# 19908                      Play It Again     country
# 19015                               Stay     country
# 19790                   Kongen av campen     country
# 19000  10,000 Hours (with Justin Bieber)     country
# 19779                     Try Losing One     country
# 19249             Baby It's Cold Outside     country
# 19405                           Hideaway     country
# 19811                         Girl Crush     country

# %%
#recommendation based on user's history
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

#input parameter "history" is a dataframe that stores artists, album_name, track_name, and genre
#latest history appears at the tail
def history_recommend(history):
    #when history is empty, randomly present 10 songs
    if history.empty:
        recommend = recset.sample(n=10, replace=False)
        return recommend[['artists', 'album_name', 'track_name', 'track_genre']]
    
    df_history = pd.merge(history, recset, on=['artists', 'album_name', 'track_name', 'track_genre'])
    #drop rows that have same columns as in history
    recom = recset.copy()
    common_rows = pd.merge(recset, df_history, on=['artists', 'album_name', 'track_name'])
    df_filtered = recom.drop(common_rows.index)

    #assign weights to history, more recent search has larger weight
    #select columns with numerical values and standardize
    weights = list(range(1, len(df_history) + 1))
    df_history_num = df_history.drop(df_history.columns[0:5], axis = 1)
    df_history_num = df_history_num.drop(df_history_num.columns[[2, 7]], axis = 1)
    df_history_standardized = pd.DataFrame(StandardScaler().fit_transform(df_history_num), columns=df_history_num.columns)

    songs = recom.copy()
    songs_num = songs.drop(songs.columns[0:4], axis = 1)
    songs_num = songs_num.drop(songs_num.columns[[2, 7, 15]], axis = 1)
    df_songs_standardized = pd.DataFrame(StandardScaler().fit_transform(songs_num), columns=songs_num.columns)

    #get average weighted vector for history
    weighted_history = df_history_standardized.mul(weights, axis=0)
    weighted_avg_history = weighted_history.sum(axis=0) / sum(weights)

    #10 NearestNeighbors
    knn = NearestNeighbors(n_neighbors=10)
    knn.fit(df_songs_standardized)
    weighted_avg_vector = weighted_avg_history.values.reshape(1, -1)
    distances, indices = knn.kneighbors(weighted_avg_vector)

    # Get the indices of the neighbors
    recommended_songs_indices = indices[0]
    recommended_songs = recom.iloc[recommended_songs_indices]
    return recommended_songs[['artists', 'album_name', 'track_name', 'track_genre']]

# %%
#test no history
nohist = pd.read_csv("data/test/testnon.csv")
history_recommend(nohist)
# Out:
#                                  artists  \
# 98708                       Idina Menzel
# 63458                  Masaharu Fukuyama
# 19786       Upchurch;Katie Noel;Chucky V
# 43532                             Exodus
# 69052                         Job Kurian
# 20741          Robin Schulz;David Guetta
# 100149                    Salon Victoria
# 85226                           Anberlin
# 41439                    Håkan Hellström
# 80713   A.R. Rahman;Rabbi Shergil;Gulzar
#
#                                            album_name  \
# 98708   Olaf's Frozen Adventure (Original Soundtrack)
# 63458                                      Good night
# 19786                                       Parachute
# 43532                             Tempo of the Damned
# 69052       Kali (Original Motion Picture Soundtrack)
# 20741                                        EDM Hits
# 100149                                        96 - 05
# 85226                          Santa's Christmas List
# 41439                      Samlade singlar! 2000-2010
# 80713                                Jab Tak Hai Jaan
#
#                                                track_name track_genre
# 98708                        Ring in the Season (Reprise)  show-tunes
# 63458                                          Good night      j-rock
# 19786   Dance with the Devil (feat. Katie Noel & Chuck...     country
# 43532                                           Blacklist      groove
# 69052                                       Chilluranthal       malay
# 20741                                           On Repeat       dance
# 100149                             La Noche Estaba Puesta         ska
# 85226                    Christmas, Baby Please Come Home   punk-rock
# 41439                               En midsommarnattsdröm        goth
# 80713                                              Challa    pop-film

# %%
#test 10 rows in history
hist = upload_recommend("data/test/test.csv")
history_recommend(hist)
# Out:
# d:\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# d:\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                        artists                   album_name  \
# 29364   Said The Sky;NÉONHÈART                    Wide-Eyed
# 28455   Said The Sky;NÉONHÈART                    Wide-Eyed
# 77771                Fábio Jr.    Fábio Jr. 2002 (Acustico)
# 74325                Fábio Jr.    Fábio Jr. 2002 (Acustico)
# 9681                  Cassiane           Não Posso Desistir
# 40185                 Cassiane           Não Posso Desistir
# 43635     Yuri Costa;Entretons                Sinal de Amor
# 95314             Willie Colón                    Fantasmas
# 109584      Kyoko Koizumi;大滝詠一  KYON3~KOIZUMI the Great 51~
# 41944          Jonas Lundqvist                 Vissa nätter
#
#                              track_name track_genre
# 29364                          Erase Me     dubstep
# 28455                          Erase Me         dub
# 77771                 Em Cada Amanhecer      pagode
# 74325                 Em Cada Amanhecer         mpb
# 9681                 Não Posso Desistir      brazil
# 40185                Não Posso Desistir      gospel
# 43635                     Sinal de Amor      groove
# 95314                              Celo       salsa
# 109584  快盗ルビイ(小泉今日子 & 大滝詠一デュエット・ヴァージョン)      techno
# 41944                 Den som ser havet        goth
